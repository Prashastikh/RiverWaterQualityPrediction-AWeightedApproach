# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import numpy as np
import random as rd
from matplotlib import pyplot as plt
from numpy import where
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #Importing Dataset

# %%
df = pd.read_csv("Gangamerge.csv")
print(df.shape)
# Out:
# (2326, 12)

# %% [markdown]
# # Data Exploration

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Temp', 'pH ', 'ORP', 'EC', 'RES', 'TDS', 'Salinity',
#        'Pressure', 'D.O.', 'Turbidity'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date      Time   Temp   pH   ...  Salinity  Pressure   D.O.  Turbidity
# 0  17-02-2020  17:04:52  20.67  8.40  ...      0.23    14.568  101.5       36.7
# 1  17-02-2020  17:05:02  20.67  8.40  ...      0.23    14.569  101.4       42.4
# 2  17-02-2020  17:05:12  20.67  8.40  ...      0.23    14.569  101.5       38.2
# 3  17-02-2020  17:05:22  20.67  8.40  ...      0.23    14.567  101.7       38.0
# 4  17-02-2020  17:05:32  20.68  8.41  ...      0.23    14.566  101.7       46.8
#
# [5 rows x 12 columns]

# %%
df.head(10)
# Out:
#          Date      Time   Temp   pH   ...  Salinity  Pressure   D.O.  Turbidity
# 0  17-02-2020  17:04:52  20.67  8.40  ...      0.23    14.568  101.5       36.7
# 1  17-02-2020  17:05:02  20.67  8.40  ...      0.23    14.569  101.4       42.4
# 2  17-02-2020  17:05:12  20.67  8.40  ...      0.23    14.569  101.5       38.2
# 3  17-02-2020  17:05:22  20.67  8.40  ...      0.23    14.567  101.7       38.0
# 4  17-02-2020  17:05:32  20.68  8.41  ...      0.23    14.566  101.7       46.8
# 5  17-02-2020  17:05:42  20.68  8.41  ...      0.23    14.571  101.5       40.7
# 6  17-02-2020  17:05:52  20.68  8.41  ...      0.23    14.570  101.8       45.5
# 7  17-02-2020  17:06:02  20.67  8.43  ...      0.22    14.569  101.9       30.7
# 8  17-02-2020  17:06:12  20.56  8.53  ...      0.22    14.569  102.1       19.5
# 9  17-02-2020  17:06:22  20.52  8.59  ...      0.22    14.567  104.7       22.9
#
# [10 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2326 non-null   object
#  1   Time       2326 non-null   object
#  2   Temp       2326 non-null   float64
#  3   pH         2326 non-null   float64
#  4   ORP        2326 non-null   float64
#  5   EC         2326 non-null   int64
#  6   RES        2326 non-null   int64
#  7   TDS        2326 non-null   int64
#  8   Salinity   2326 non-null   float64
#  9   Pressure   2326 non-null   float64
#  10  D.O.       2326 non-null   float64
#  11  Turbidity  2326 non-null   float64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 218.2+ KB

# %%
df = pd.DataFrame(df)

# %%
print(df)
# Out:
#             Date      Time   Temp   pH   ...  Salinity  Pressure   D.O.  Turbidity
# 0     17-02-2020  17:04:52  20.67  8.40  ...      0.23    14.568  101.5       36.7
# 1     17-02-2020  17:05:02  20.67  8.40  ...      0.23    14.569  101.4       42.4
# 2     17-02-2020  17:05:12  20.67  8.40  ...      0.23    14.569  101.5       38.2
# 3     17-02-2020  17:05:22  20.67  8.40  ...      0.23    14.567  101.7       38.0
# 4     17-02-2020  17:05:32  20.68  8.41  ...      0.23    14.566  101.7       46.8
# ...          ...       ...    ...   ...  ...       ...       ...    ...        ...
# 2321  20-02-2020  09:45:59  20.48  8.94  ...      0.22    14.698  124.9       12.3
# 2322  20-02-2020  09:46:09  20.50  8.96  ...      0.22    14.697  125.6       11.9
# 2323  20-02-2020  09:46:19  20.51  8.98  ...      0.22    14.698  125.9       11.8
# 2324  20-02-2020  09:46:29  20.50  8.95  ...      0.22    14.700  125.7       11.6
# ...

# %%
df.describe()
# Out:
#               Temp          pH   ...         D.O.    Turbidity
# count  2326.000000  2326.000000  ...  2326.000000  2326.000000
# mean     20.345739     8.964536  ...   122.168831    16.952752
# std       0.308839     0.184965  ...     9.319878    39.316080
# min      19.930000     6.960000  ...    52.500000    10.100000
# 25%      20.220000     8.900000  ...   116.125000    12.200000
# 50%      20.320000     9.000000  ...   121.800000    12.900000
# 75%      20.390000     9.067500  ...   127.200000    13.800000
# max      24.840000     9.270000  ...   154.500000  1000.000000
#
# [8 rows x 10 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Time                 object
# Temp                float64
# pH                  float64
# ORP                 float64
# EC                    int64
# RES                   int64
# TDS                   int64
# Salinity            float64
# Pressure            float64
# D.O.                float64
# Turbidity           float64
# dtype: object

# %% [markdown]
# # Visualization using Histograms

# %%
df.hist(bins=50,figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8d3645e400>,
# ...
#       dtype=object)

# %%
df["Day"] = df["Date"].dt.day

# %%
df.head()
# Out:
#         Date      Time   Temp   pH   ...  Pressure   D.O.  Turbidity  Day
# 0 2020-02-17  17:04:52  20.67  8.40  ...    14.568  101.5       36.7   17
# 1 2020-02-17  17:05:02  20.67  8.40  ...    14.569  101.4       42.4   17
# 2 2020-02-17  17:05:12  20.67  8.40  ...    14.569  101.5       38.2   17
# 3 2020-02-17  17:05:22  20.67  8.40  ...    14.567  101.7       38.0   17
# 4 2020-02-17  17:05:32  20.68  8.41  ...    14.566  101.7       46.8   17
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#            Date      Time   Temp   pH   ...  Pressure   D.O.  Turbidity  Day
# 2321 2020-02-20  09:45:59  20.48  8.94  ...    14.698  124.9       12.3   20
# 2322 2020-02-20  09:46:09  20.50  8.96  ...    14.697  125.6       11.9   20
# 2323 2020-02-20  09:46:19  20.51  8.98  ...    14.698  125.9       11.8   20
# 2324 2020-02-20  09:46:29  20.50  8.95  ...    14.700  125.7       11.6   20
# 2325 2020-02-20  09:46:39  20.49  8.93  ...    14.695  125.7       13.6   20
#
# [5 rows x 13 columns]

# %% [markdown]
# #Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
attributes = ['Date', 'Time', 'Temp', 'pH ', 'ORP', 'EC', 'RES', 'TDS', 'Salinity',
       'Pressure', 'D.O.', 'Turbidity']
scatter_matrix(df[attributes], figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8d35b09518>,
# ...
#       dtype=object)

# %% [markdown]
# #Correlation Matrix

# %%
plt.matshow(df.corr())
plt.show()

# %%
rs = np.random.RandomState(0)
df1 = pd.DataFrame(rs.rand(12, 12))
corr = df1.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col1 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col2 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col4 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col5 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_d25feb86_d355_11ea_aabd_0242ac1c0002row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
df.tail()
# Out:
#            Date      Time   Temp   pH   ...  Pressure   D.O.  Turbidity  Day
# 2321 2020-02-20  09:45:59  20.48  8.94  ...    14.698  124.9       12.3   20
# 2322 2020-02-20  09:46:09  20.50  8.96  ...    14.697  125.6       11.9   20
# 2323 2020-02-20  09:46:19  20.51  8.98  ...    14.698  125.9       11.8   20
# 2324 2020-02-20  09:46:29  20.50  8.95  ...    14.700  125.7       11.6   20
# 2325 2020-02-20  09:46:39  20.49  8.93  ...    14.695  125.7       13.6   20
#
# [5 rows x 13 columns]

# %% [markdown]
# #Plotting Data According to the Date

# %%
x = df['Day']
# corresponding y axis values 
y = df['Temp']   
# plotting the points  
plt.plot(x, y)   
# naming the x axis 
plt.xlabel('Day') 
# naming the y axis 
plt.ylabel('Temp')  
# giving a title to my graph 
plt.title('Temp_through_days')   
# function to show the plot 
plt.show() 

x = df['Day']
y = df['ORP'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('Oxidation_Reduction_Potential')
plt.title('ORP_through_days')
plt.show()

x = df['Day']
y = df['EC'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('EC')
plt.title('Electrical_conductivity_through_days')
plt.show()

x = df['Day']
y = df['TDS'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('TDS')
plt.title('Total_Dissoved_solids_through_days')
plt.show()

x = df['Day']
y = df['Salinity'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('Salinity')
plt.title('Salinity_through_days')
plt.show()

x = df['Day']
y = df['Pressure'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('Pressure')
plt.title('Pressure_through_days')
plt.show()

x = df['Day']
y = df['D.O.'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('D.O.')
plt.title('Dissoved_Oxygen_through_days')
plt.show()

x = df['Day']
y = df['Turbidity'] 
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('Turbidity')
plt.title('Turbidity_through_days')
plt.show()

x = df['Day']
y = df['pH ']
plt.plot(x, y)
plt.xlabel('Day') 
plt.ylabel('pH')
plt.title('pH_through_days')
plt.show()

# %%
# line 1 points 
x1 = df['Day'] 
y1 = df['Temp']
# plotting the line 1 points  
plt.plot(x1, y1, label = "Temp")  

# line 2 points 
x2 = df['Day']  
y2 = df['ORP']
# plotting the line 2 points  
plt.plot(x2, y2, label = "ORP") 

x3 = df['Day']  
y3 = df['EC']
# plotting the line 2 points  
plt.plot(x3, y3, label = "EC")  

x4 = df['Day']  
y4 = df['pH ']
# plotting the line 2 points  
plt.plot(x4, y4, label = "pH ") 

x5 = df['Day']  
y5 = df['RES']
# plotting the line 2 points 
plt.plot(x5, y5, label = "RES") 

x6 = df['Day']  
y6 = df['Salinity']
# plotting the line 2 points  
plt.plot(x6, y6, label = "Salinity") 

x7 = df['Day']  
y7 = df['Pressure']
# plotting the line 2 points  
plt.plot(x7, y7, label = "Pressure") 

x8 = df['Day']  
y8 = df['TDS']
# plotting the line 2 points  
plt.plot(x8, y8, label = "TDS") 

x9 = df['Day']  
y9 = df['D.O.']
# plotting the line 2 points  
plt.plot(x7, y7, label = "D.O.") 

x7 = df['Day']  
y7 = df['Turbidity']
# plotting the line 2 points  
plt.plot(x7, y7, label = "Turbidity") 

# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
# giving a title to my graph
plt.title('Parameters distribution')  
# show a legend on the plot 
# function to show the plot 
plt.show()

# %%
x_var = 'Temp'
groupby_var = 'Day'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(12,8), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])}, ncol = 2,loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Distribution of Temperature colored by Day", fontsize=22)
plt.xlabel(x_var, fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.ylim(0, 150)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()

# %%
# Prepare data
x_var = 'pH '
groupby_var = 'Day'
df_agg = df.loc[:, [x_var, groupby_var]].groupby(groupby_var)
vals = [df[x_var].values.tolist() for i, df in df_agg]

# Draw
plt.figure(figsize=(12,8), dpi= 80)
colors = [plt.cm.Spectral(i/float(len(vals)-1)) for i in range(len(vals))]
n, bins, patches = plt.hist(vals, 30, stacked=True, density=False, color=colors[:len(vals)])

# Decoration
plt.legend({group:col for group, col in zip(np.unique(df[groupby_var]).tolist(), colors[:len(vals)])}, ncol = 2,loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Distribution of pH colored by Day", fontsize=22)
plt.xlabel(x_var)
plt.ylabel("Frequency")
plt.ylim(0, 300)
plt.xticks(ticks=bins[::3], labels=[round(b,1) for b in bins[::3]])
plt.show()
